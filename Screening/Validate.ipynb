# %%
import torch

from model import LitModel

# %%
model = LitModel(num_layers=10).load_from_checkpoint("./chkpts/epoch=69-step=2520.ckpt")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 model = LitModel(num_layers=10).load_from_checkpoint("./chkpts/epoch=69-step=2520.ckpt")
#
# File ~/miniconda3/envs/mof/lib/python3.10/site-packages/pytorch_lightning/core/saving.py:137, in ModelIO.load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#      57 @classmethod
#      58 def load_from_checkpoint(
#      59     cls,
#    (...)
#      64     **kwargs: Any,
#      65 ) -> Self:  # type: ignore[valid-type]
#      66     r"""
#      67     Primary way of loading a model from a checkpoint. When Lightning saves a checkpoint
#      68     it stores the arguments passed to ``__init__``  in the checkpoint under ``"hyper_parameters"``.
#    (...)
#     135         y_hat = pretrained_model(x)
#     136     """
# ...

# %%
# Out:
# {'epoch': 32, 'global_step': 1170, 'pytorch-lightning_version': '1.8.1', 'state_dict': OrderedDict([('model.conv1.weight', tensor([[[[[ 1.3198e-02, -3.8489e-02,  4.3600e-02,  ...,  2.2165e-02,
#             -4.3592e-02, -2.3187e-02],
#            [ 5.5076e-02, -4.5370e-02, -4.8084e-02,  ..., -6.7058e-03,
#              3.5495e-02, -9.4937e-02],
#            [ 1.5640e-02, -3.3678e-02, -8.5982e-03,  ..., -6.6505e-03,
#              7.7903e-03, -1.6306e-02],
#            ...,
#            [ 8.7245e-03,  2.4948e-02,  2.7954e-02,  ...,  6.0865e-02,
#              5.1310e-02, -4.9777e-02],
#            [-1.7755e-02,  3.6389e-02, -2.2865e-02,  ..., -9.8076e-04,
#              1.3125e-02,  1.8160e-02],
#            [ 6.2895e-02, -8.6474e-02, -1.3800e-02,  ...,  2.1301e-02,
#              3.1972e-03,  5.4350e-03]],
#
#           [[-1.2732e-02, -2.7731e-03, -6.5755e-02,  ...,  2.5349e-02,
#              8.2866e-03,  2.1289e-02],
# ...
